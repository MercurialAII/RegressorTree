# %%
import numpy as np
from sklearn.datasets import load_diabetes



class Tree:

    def __init__(self, x, y, left=None, right=None, parent=None, min_samples_split=2, min_samples_leaf=1):
        self.__x = x
        self.__y = y
        self.__right = right
        self.__left = left
        self.__parent = parent
        self.__min_samples_split = min_samples_split
        self.__min_samples_leaf = min_samples_leaf
        self.__is_leaf = 0
        self.__best_split_feature = None
        self.__res = None

    @property
    def x(self):
        return self.__x

    @x.setter
    def x(self, x):
        self.__x = x

    @property
    def y(self):
        return self.__y

    @y.setter
    def y(self, y):
        self.__y = y

    @property
    def left(self):
        return self.__left

    @left.setter
    def left(self, left):
        self.__left = left

    @property
    def right(self):
        return self.__right

    @right.setter
    def right(self, right):
        self.__right = right

    @property
    def parent(self):
        return self.__parent

    @parent.setter
    def parent(self, parent):
        self.__parent = parent

    @property
    def res(self):
        return self.__res
    
    @res.setter
    def res(self, res):
        self.__res = res

    @property
    def best_split_feature(self):
        return self.__best_split_feature

    @best_split_feature.setter
    def best_split_feature(self, best_split_feature):
        self.__best_split_feature = best_split_feature

    @property
    def label(self):
        return np.mean(self.y)

    @property
    def is_leaf(self):
        return self.__is_leaf

    @is_leaf.setter
    def is_leaf(self, is_leaf):
        self.__is_leaf = is_leaf

    # 计算残差平方和
    def mse(self, y=None):

        if y is None:
            y = self.y

        return np.sum(np.square(y - np.mean(y))) / y.size

    # 搜索最佳特征和分裂点
    def search_best_split(self):

        _best_split_feature = None
        _best_split_dot = None
        _best_split_mse = self.mse()
        
        if self.y.size <= self.__min_samples_split or np.unique(self.y).size <= self.__min_samples_leaf
            or _best_split_mse == 0:
            self.is_leaf = 1
            self.res = ['samples = %s' % self.y.size, 'label = %s' % round(np.mean(self.y),2),
            'mse = %s'%round(self.mse(),2)]
            return ['samples = %s' % self.y.size, 'label = %s' % round(np.mean(self.y),2),
            'mse = %s'%round(self.mse(),2)]

        split_dict = {}
        
        for i in range(self.x.shape[1]):
            
            split_dict[i] = []
            uni_x = np.unique(self.x[:, i])
            len_x = uni_x.size

            j = 0

            while j <= len_x - 1 - 1:

                split_dot = (uni_x[j] + uni_x[j + 1]) / 2

                y1 = self.y[self.x[:, i] <= split_dot]
                y2 = self.y[self.x[:, i] > split_dot]

                mse_y1 = self.mse(y1)
                mse_y2 = self.mse(y2)

                mse_total =  y1.size/self.y.size*mse_y1 +  y2.size/self.y.size*mse_y2

                if mse_total <= _best_split_mse:
                    _best_split_feature = i
                    _best_split_dot = split_dot
                    _best_split_mse = mse_total

                _split = {'split_dot': _best_split_dot, 'mse_total': _best_split_mse}

                split_dict[i].append(_split)

                j = j + 1
            
            
        self.__best_split_feature = [_best_split_feature, _best_split_dot]
        self.res = ['x[%s]<=%s' % (_best_split_feature, round(_best_split_dot,4)), 'mse = %s'%round(self.mse(),2)
                    , 'samples = %s' % self.y.size]
        return _best_split_feature, _best_split_dot, _best_split_mse, split_dict

    def split(self):


        if self.is_leaf == 1:
            return self.res

        _best_split_feature, _best_split_dot, _best_split_mse, split_dict = self.search_best_split()
        print('best_split_feature:%s, best_split_dot:%s'%(_best_split_feature, round(_best_split_dot,4)))
        self.left = Tree(self.x[self.x[:, _best_split_feature] <= _best_split_dot],
                         self.y[self.x[:, _best_split_feature] <= _best_split_dot])
        self.right = Tree(self.x[self.x[:, _best_split_feature] > _best_split_dot],
                          self.y[self.x[:, _best_split_feature] > _best_split_dot])
        samples = self.y.size

        return self.res


class RegressorTree:

    def __init__(self, max_depth=5, min_samples_split=2, min_samples_leaf=1):

        self.__min_samples_split = min_samples_split
        self.__min_samples_leaf = min_samples_leaf
        self.__max_depth = max_depth
        self.__children = []
        self.__parents = []
        self.__root = None

    def fit(self, x, y, min_samples_split=2, min_samples_leaf=1):

        depth = 1
        self.__root = Tree(x, y)
        self.__parents.append(self.__root)
        
        print('begin fit, root = %s'%hex(id(self.__root)))
        print('----------------------------------')
        
        #广度优先
        while depth <= self.__max_depth:
            
            print('--------------depth: %s ----------------'%depth)
            
            for i in self.__parents:
                
                i.search_best_split()
                print('当前分裂节点： %s, 节点内容： %s, 节点标签: %s, 是否叶子节点: %s'%(hex(id(i)), i.res, round(i.label,2), i.is_leaf))
                
                if i == None or i.is_leaf==1:
                    continue
                i.split()
                self.__children.append(i.left)
                self.__children.append(i.right)
                
                if depth == self.__max_depth:
                    i.left.is_leaf = 1
                    i.right.is_leaf = 1
                    
                
                
                print('当前节点生成左子节点：%s, 父节点为：%s'%(
                        hex(id(i.left)),hex(id(i))
                        ))
                print('当前节点生成右子节点：%s,  父节点为：%s'%(
                        hex(id(i.right)),hex(id(i))
                        ))
                print('------')
            self.__parents = []
            self.__parents.extend(self.__children)
            self.__children = []

            depth = depth + 1

    def predict(self, x1):

        current_node = self.__root
        is_leaf = current_node.is_leaf
        
        #print('predict begin')
        
        while is_leaf == 0:
                      
            best_feature = current_node.best_split_feature
            #print('current_node_id: %s'%hex(id(current_node)),'current_node_res : %s'%current_node.res,
            #      'is_leaf : %s'%current_node.is_leaf, 'label: %s'%current_node.label)
            
            if x1[best_feature[0]] <= best_feature[1]:
                #print('go left')
                current_node = current_node.left

            else:
                #print('go right')
                current_node = current_node.right
        
            is_leaf = current_node.is_leaf
            
        return current_node.label

# %%
x, y = load_diabetes(return_X_y=True)
clf =  RegressorTree(max_depth=5)
clf.fit(x, y)
# Out:
# begin fit, root = 0x289838b93d0
# ----------------------------------
# --------------depth: 1 ----------------
# 当前分裂节点： 0x289838b93d0, 节点内容： ['x[8]<=-0.0038', 'mse = 5929.88', 'samples = 442'], 节点标签: 152.13, 是否叶子节点: 0
# best_split_feature:8, best_split_dot:-0.0038
# 当前节点生成左子节点：0x28985c61280, 父节点为：0x289838b93d0
# 当前节点生成右子节点：0x289885e2e20,  父节点为：0x289838b93d0
# ------
# --------------depth: 2 ----------------
# 当前分裂节点： 0x28985c61280, 节点内容： ['x[2]<=0.0062', 'mse = 3240.82', 'samples = 218'], 节点标签: 109.99, 是否叶子节点: 0
# best_split_feature:2, best_split_dot:0.0062
# 当前节点生成左子节点：0x289885e2fa0, 父节点为：0x28985c61280
# 当前节点生成右子节点：0x289838b97f0,  父节点为：0x28985c61280
# ------
# 当前分裂节点： 0x289885e2e20, 节点内容： ['x[2]<=0.0148', 'mse = 5135.61', 'samples = 224'], 节点标签: 193.15, 是否叶子节点: 0
# best_split_feature:2, best_split_dot:0.0148
# 当前节点生成左子节点：0x289838b9220, 父节点为：0x289885e2e20
# 当前节点生成右子节点：0x28983944bb0,  父节点为：0x289885e2e20
# ------
# --------------depth: 3 ----------------
# 当前分裂节点： 0x289885e2fa0, 节点内容： ['x[6]<=0.021', 'mse = 2143.97', 'samples = 171'], 节点标签: 96.31, 是否叶子节点: 0
# best_split_feature:6, best_split_dot:0.021
# 当前节点生成左子节点：0x28983944b80, 父节点为：0x289885e2fa0
# 当前节点生成右子节点：0x289838be2b0,  父节点为：0x289885e2fa0
# ------
# 当前分裂节点： 0x289838b97f0, 节点内容： ['x[0]<=-0.08', 'mse = 4075.08', 'samples = 47'], 节点标签: 159.74, 是否叶子节点: 0
# best_split_feature:0, best_split_dot:-0.08
# 当前节点生成左子节点：0x289838be160, 父节点为：0x289838b97f0
# 当前节点生成右子节点：0x289838bed60,  父节点为：0x289838b97f0
# ------
# 当前分裂节点： 0x289838b9220, 节点内容： ['x[2]<=-0.0218', 'mse = 4095.84', 'samples = 116'], 节点标签: 162.68, 是否叶子节点: 0
# best_split_feature:2, best_split_dot:-0.0218
# 当前节点生成左子节点：0x289838becd0, 父节点为：0x289838b9220
# 当前节点生成右子节点：0x289838be1c0,  父节点为：0x289838b9220
# ------
# 当前分裂节点： 0x28983944bb0, 节点内容： ['x[2]<=0.0687', 'mse = 4184.05', 'samples = 108'], 节点标签: 225.88, 是否叶子节点: 0
# best_split_feature:2, best_split_dot:0.0687
# 当前节点生成左子节点：0x289838be100, 父节点为：0x28983944bb0
# 当前节点生成右子节点：0x289838be070,  父节点为：0x28983944bb0
# ------
# --------------depth: 4 ----------------
# 当前分裂节点： 0x28983944b80, 节点内容： ['x[5]<=0.0911', 'mse = 2856.85', 'samples = 87'], 节点标签: 108.8, 是否叶子节点: 0
# best_split_feature:5, best_split_dot:0.0911
# 当前节点生成左子节点：0x289838be280, 父节点为：0x28983944b80
# 当前节点生成右子节点：0x289838be040,  父节点为：0x28983944b80
# ------
# 当前分裂节点： 0x289838be2b0, 节点内容： ['x[1]<=0.003', 'mse = 1076.47', 'samples = 84'], 节点标签: 83.37, 是否叶子节点: 0
# best_split_feature:1, best_split_dot:0.003
# 当前节点生成左子节点：0x289838be220, 父节点为：0x289838be2b0
# 当前节点生成右子节点：0x289838be0a0,  父节点为：0x289838be2b0
# ------
# 当前分裂节点： 0x289838be160, 节点内容： ['samples = 2', 'label = 274.0', 'mse = 784.0'], 节点标签: 274.0, 是否叶子节点: 1
# 当前分裂节点： 0x289838bed60, 节点内容： ['x[3]<=0.0098', 'mse = 3615.38', 'samples = 45'], 节点标签: 154.67, 是否叶子节点: 0
# best_split_feature:3, best_split_dot:0.0098
# 当前节点生成左子节点：0x289838be130, 父节点为：0x289838bed60
# 当前节点生成右子节点：0x289838bea00,  父节点为：0x289838bed60
# ------
# 当前分裂节点： 0x289838becd0, 节点内容： ['x[4]<=-0.0525', 'mse = 2869.5', 'samples = 42'], 节点标签: 137.69, 是否叶子节点: 0
# best_split_feature:4, best_split_dot:-0.0525
# 当前节点生成左子节点：0x289838bef10, 父节点为：0x289838becd0
# 当前节点生成右子节点：0x289838be2e0,  父节点为：0x289838becd0
# ------
# 当前分裂节点： 0x289838be1c0, 节点内容： ['x[8]<=0.0144', 'mse = 4236.22', 'samples = 74'], 节点标签: 176.86, 是否叶子节点: 0
# best_split_feature:8, best_split_dot:0.0144
# 当前节点生成左子节点：0x28983918160, 父节点为：0x289838be1c0
# 当前节点生成右子节点：0x289839189d0,  父节点为：0x289838be1c0
# ------
# 当前分裂节点： 0x289838be100, 节点内容： ['x[3]<=0.0167', 'mse = 3966.12', 'samples = 77'], 节点标签: 208.57, 是否叶子节点: 0
# best_split_feature:3, best_split_dot:0.0167
# 当前节点生成左子节点：0x28983918970, 父节点为：0x289838be100
# 当前节点生成右子节点：0x28983918190,  父节点为：0x289838be100
# ------
# 当前分裂节点： 0x289838be070, 节点内容： ['x[5]<=0.0225', 'mse = 2133.02', 'samples = 31'], 节点标签: 268.87, 是否叶子节点: 0
# best_split_feature:5, best_split_dot:0.0225
# 当前节点生成左子节点：0x289839189a0, 父节点为：0x289838be070
# 当前节点生成右子节点：0x28983918a00,  父节点为：0x289838be070
# ------
# --------------depth: 5 ----------------
# 当前分裂节点： 0x289838be280, 节点内容： ['x[1]<=0.003', 'mse = 2496.9', 'samples = 85'], 节点标签: 105.68, 是否叶子节点: 0
# best_split_feature:1, best_split_dot:0.003
# 当前节点生成左子节点：0x289839181c0, 父节点为：0x289838be280
# 当前节点生成右子节点：0x28983918a90,  父节点为：0x289838be280
# ------
# 当前分裂节点： 0x289838be040, 节点内容： ['samples = 2', 'label = 241.5', 'mse = 132.25'], 节点标签: 241.5, 是否叶子节点: 1
# 当前分裂节点： 0x289838be220, 节点内容： ['x[2]<=-0.0628', 'mse = 1193.75', 'samples = 64'], 节点标签: 88.0, 是否叶子节点: 0
# best_split_feature:2, best_split_dot:-0.0628
# 当前节点生成左子节点：0x28983918a30, 父节点为：0x289838be220
# 当前节点生成右子节点：0x289839181f0,  父节点为：0x289838be220
# ------
# 当前分裂节点： 0x289838be0a0, 节点内容： ['x[0]<=0.0054', 'mse = 412.95', 'samples = 20'], 节点标签: 68.55, 是否叶子节点: 0
# best_split_feature:0, best_split_dot:0.0054
# 当前节点生成左子节点：0x28983918a60, 父节点为：0x289838be0a0
# 当前节点生成右子节点：0x28983918ac0,  父节点为：0x289838be0a0
# ------
# 当前分裂节点： 0x289838be130, 节点内容： ['x[4]<=-0.0477', 'mse = 1713.25', 'samples = 26'], 节点标签: 135.54, 是否叶子节点: 0
# best_split_feature:4, best_split_dot:-0.0477
# 当前节点生成左子节点：0x28983918700, 父节点为：0x289838be130
# 当前节点生成右子节点：0x28983918b50,  父节点为：0x289838be130
# ------
# 当前分裂节点： 0x289838bea00, 节点内容： ['x[2]<=0.0391', 'mse = 5032.45', 'samples = 19'], 节点标签: 180.84, 是否叶子节点: 0
# best_split_feature:2, best_split_dot:0.0391
# 当前节点生成左子节点：0x28983918af0, 父节点为：0x289838bea00
# 当前节点生成右子节点：0x289839186a0,  父节点为：0x289838bea00
# ------
# 当前分裂节点： 0x289838bef10, 节点内容： ['x[5]<=-0.0694', 'mse = 1904.14', 'samples = 6'], 节点标签: 193.83, 是否叶子节点: 0
# best_split_feature:5, best_split_dot:-0.0694
# 当前节点生成左子节点：0x28983918b20, 父节点为：0x289838bef10
# 当前节点生成右子节点：0x28983918b80,  父节点为：0x289838bef10
# ------
# 当前分裂节点： 0x289838be2e0, 节点内容： ['x[9]<=0.0424', 'mse = 2417.5', 'samples = 36'], 节点标签: 128.33, 是否叶子节点: 0
# best_split_feature:9, best_split_dot:0.0424
# 当前节点生成左子节点：0x28983918670, 父节点为：0x289838be2e0
# 当前节点生成右子节点：0x28983918c10,  父节点为：0x289838be2e0
# ------
# 当前分裂节点： 0x28983918160, 节点内容： ['x[6]<=-0.0452', 'mse = 3862.5', 'samples = 18'], 节点标签: 139.94, 是否叶子节点: 0
# best_split_feature:6, best_split_dot:-0.0452
# 当前节点生成左子节点：0x28983918cd0, 父节点为：0x28983918160
# 当前节点生成右子节点：0x28983918250,  父节点为：0x28983918160
# ------
# 当前分裂节点： 0x289839189d0, 节点内容： ['x[9]<=0.0341', 'mse = 3777.37', 'samples = 56'], 节点标签: 188.73, 是否叶子节点: 0
# best_split_feature:9, best_split_dot:0.0341
# 当前节点生成左子节点：0x28983918be0, 父节点为：0x289839189d0
# 当前节点生成右子节点：0x28983918c40,  父节点为：0x289839189d0
# ------
# 当前分裂节点： 0x28983918970, 节点内容： ['x[9]<=0.1128', 'mse = 5206.96', 'samples = 33'], 节点标签: 178.21, 是否叶子节点: 0
# best_split_feature:9, best_split_dot:0.1128
# 当前节点生成左子节点：0x289839182b0, 父节点为：0x28983918970
# 当前节点生成右子节点：0x28983918610,  父节点为：0x28983918970
# ------
# 当前分裂节点： 0x28983918190, 节点内容： ['x[8]<=0.074', 'mse = 1825.77', 'samples = 44'], 节点标签: 231.34, 是否叶子节点: 0
# best_split_feature:8, best_split_dot:0.074
# 当前节点生成左子节点：0x28983918bb0, 父节点为：0x28983918190
# 当前节点生成右子节点：0x28983918c70,  父节点为：0x28983918190
# ------
# 当前分裂节点： 0x289839189a0, 节点内容： ['x[8]<=0.0318', 'mse = 1073.61', 'samples = 19'], 节点标签: 290.42, 是否叶子节点: 0
# best_split_feature:8, best_split_dot:0.0318
# 当前节点生成左子节点：0x28983918790, 父节点为：0x289839189a0
# 当前节点生成右子节点：0x28983918730,  父节点为：0x289839189a0
# ------
# 当前分裂节点： 0x28983918a00, 节点内容： ['x[5]<=0.0242', 'mse = 1910.85', 'samples = 12'], 节点标签: 234.75, 是否叶子节点: 0
# best_split_feature:5, best_split_dot:0.0242
# 当前节点生成左子节点：0x28983918ca0, 父节点为：0x28983918a00
# 当前节点生成右子节点：0x28983918490,  父节点为：0x28983918a00
# ------
